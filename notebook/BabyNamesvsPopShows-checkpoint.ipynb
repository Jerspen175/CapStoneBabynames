# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
BN = pd.read_csv('../data/NationalNames.csv')
BNS = pd.read_csv('../data/StateNames.csv')

# %%
pd.DataFrame(BN)
# Out:
#               Id       Name  Year Gender  Count
# 0              1       Mary  1880      F   7065
# 1              2       Anna  1880      F   2604
# 2              3       Emma  1880      F   2003
# 3              4  Elizabeth  1880      F   1939
# 4              5     Minnie  1880      F   1746
# ...          ...        ...   ...    ...    ...
# 1825428  1825429     Zykeem  2014      M      5
# 1825429  1825430     Zymeer  2014      M      5
# 1825430  1825431    Zymiere  2014      M      5
# 1825431  1825432      Zyran  2014      M      5
# 1825432  1825433      Zyrin  2014      M      5
#
# [1825433 rows x 5 columns]

# %%
pd.DataFrame(MT)
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 3      tm127384            Monty Python and the Holy Grail  MOVIE
# 4      tm120801                            The Dirty Dozen  MOVIE
# ...         ...                                        ...    ...
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# ...

# %%
pd.DataFrame(BNS)
# Out:
#               Id      Name  Year Gender State  Count
# 0              1      Mary  1910      F    AK     14
# 1              2     Annie  1910      F    AK     12
# 2              3      Anna  1910      F    AK     10
# 3              4  Margaret  1910      F    AK      8
# 4              5     Helen  1910      F    AK      7
# ...          ...       ...   ...    ...   ...    ...
# 5647421  5647422      Seth  2014      M    WY      5
# 5647422  5647423   Spencer  2014      M    WY      5
# 5647423  5647424      Tyce  2014      M    WY      5
# 5647424  5647425    Victor  2014      M    WY      5
# 5647425  5647426    Waylon  2014      M    WY      5
#
# [5647426 rows x 6 columns]

# %%
BN['Count'].max()
# Out:
# 99680

# %%
BN['Count']
# Out:
# 0        13
# 1        21
# 2        49
# 3        38
# 4        36
#          ..
# 49504    10
# 49505    10
# 49506    10
# 49507    10
# 49508    10
# Name: Count, Length: 49509, dtype: int64

# %%
BN[BN['Year']== 2000]
# Out:
#               Id     Name  Year Gender  Count
# 1332538  1332539    Emily  2000      F  25952
# 1332539  1332540   Hannah  2000      F  23073
# 1332540  1332541  Madison  2000      F  19967
# 1332541  1332542   Ashley  2000      F  17995
# 1332542  1332543    Sarah  2000      F  17687
# ...          ...      ...   ...    ...    ...
# 1362296  1362297     Zeph  2000      M      5
# 1362297  1362298    Zeven  2000      M      5
# 1362298  1362299    Ziggy  2000      M      5
# 1362299  1362300       Zo  2000      M      5
# 1362300  1362301    Zyier  2000      M      5
#
# [29763 rows x 5 columns]

# %%
BN[BN['Year']==2001]
# Out:
#               Id     Name  Year Gender  Count
# 1362301  1362302    Emily  2001      F  25052
# 1362302  1362303  Madison  2001      F  22158
# 1362303  1362304   Hannah  2001      F  20707
# 1362304  1362305   Ashley  2001      F  16524
# 1362305  1362306   Alexis  2001      F  16396
# ...          ...      ...   ...    ...    ...
# 1392557  1392558     Zyad  2001      M      5
# 1392558  1392559    Zyere  2001      M      5
# 1392559  1392560    Zykel  2001      M      5
# 1392560  1392561    Zyrek  2001      M      5
# 1392561  1392562  Zyshaun  2001      M      5
#
# [30261 rows x 5 columns]

# %%
BN[(BN['Name'] == 'Crystal') & (BN['Year'] >= 1979)]
# Out:
#               Id     Name  Year Gender  Count
# 844725    844726  Crystal  1979      F  13466
# 858006    858007  Crystal  1979      M     48
# 863755    863756  Crystal  1980      F  14258
# 877136    877137  Crystal  1980      M     55
# 883192    883193  Crystal  1981      F  15880
# ...          ...      ...   ...    ...    ...
# 1688389  1688390  Crystal  2010      M      6
# 1691972  1691973  Crystal  2011      F    932
# 1725886  1725887  Crystal  2012      F    815
# 1759649  1759650  Crystal  2013      F    658
# 1792865  1792866  Crystal  2014      F    657
#
# [65 rows x 5 columns]

# %%
BN[(BN['Name'] == 'Akeem') & (BN['Year'] >= 1980)]
# Out:
#               Id   Name  Year Gender  Count
# 880037    880038  Akeem  1980      M      9
# 899866    899867  Akeem  1981      M      8
# 916771    916772  Akeem  1982      M     31
# 935002    935003  Akeem  1983      M    192
# 954429    954430  Akeem  1984      M    254
# 974409    974410  Akeem  1985      M    160
# 994633    994634  Akeem  1986      M    283
# 1015861  1015862  Akeem  1987      M    178
# 1037840  1037841  Akeem  1988      M    221
# 1060665  1060666  Akeem  1989      M    459
# 1085086  1085087  Akeem  1990      M    570
# 1110105  1110106  Akeem  1991      M    419
# 1135435  1135436  Akeem  1992      M    325
# 1161139  1161140  Akeem  1993      M    242
# 1187092  1187093  Akeem  1994      M    222
# 1213201  1213202  Akeem  1995      M    174
# 1239508  1239509  Akeem  1996      M    146
# 1266380  1266381  Akeem  1997      M    116
# 1293939  1293940  Akeem  1998      M     97
# 1322641  1322642  Akeem  1999      M     61
# ...

# %%
BN[(BN['Name'] == 'Barbie') & (BN['Year'] >= 1960)]
# Out:
#               Id    Name  Year Gender  Count
# 573640    573641  Barbie  1960      F     82
# 585298    585299  Barbie  1961      F    132
# 597400    597401  Barbie  1962      F    151
# 609537    609538  Barbie  1963      F    171
# 621780    621781  Barbie  1964      F    190
# 634334    634335  Barbie  1965      F    121
# 646298    646299  Barbie  1966      F    118
# 658289    658290  Barbie  1967      F    163
# 670857    670858  Barbie  1968      F    121
# 683969    683970  Barbie  1969      F     97
# 697637    697638  Barbie  1970      F    118
# 712488    712489  Barbie  1971      F    105
# 727923    727924  Barbie  1972      F     81
# 743449    743450  Barbie  1973      F     72
# 759105    759106  Barbie  1974      F     76
# 775307    775308  Barbie  1975      F     83
# 792174    792175  Barbie  1976      F     89
# 809582    809583  Barbie  1977      F     94
# 827971    827972  Barbie  1978      F     76
# 846263    846264  Barbie  1979      F     74
# ...

# %%
BN[(BN['Name'] == 'Ken') & (BN['Year'] >= 1956)]
# Out:
#               Id Name  Year Gender  Count
# 533423    533424  Ken  1956      M    655
# 544821    544822  Ken  1957      M   1181
# 556361    556362  Ken  1958      M   1526
# 568047    568048  Ken  1959      M   1663
# 579950    579951  Ken  1960      M   1777
# ...          ...  ...   ...    ...    ...
# 1679413  1679414  Ken  2010      M     68
# 1712862  1712863  Ken  2011      M     88
# 1746472  1746473  Ken  2012      M    107
# 1780262  1780263  Ken  2013      M     75
# 1813226  1813227  Ken  2014      M     84
#
# [64 rows x 5 columns]

# %%
BN[(BN['Name'] == 'Lorelai') & (BN['Year'] >= 1980)]
# Out:
#               Id     Name  Year Gender  Count
# 1368024  1368025  Lorelai  2001      F     20
# 1394926  1394927  Lorelai  2002      F     68
# 1425174  1425175  Lorelai  2003      F     87
# 1456195  1456196  Lorelai  2004      F     99
# 1487549  1487550  Lorelai  2005      F    187
# 1519855  1519856  Lorelai  2006      F    262
# 1553799  1553800  Lorelai  2007      F    321
# 1588752  1588753  Lorelai  2008      F    312
# 1623685  1623686  Lorelai  2009      F    363
# 1658340  1658341  Lorelai  2010      F    371
# 1692432  1692433  Lorelai  2011      F    338
# 1726239  1726240  Lorelai  2012      F    376
# 1759986  1759987  Lorelai  2013      F    336
# 1793209  1793210  Lorelai  2014      F    335

# %%
BN[(BN['Name'] == 'Obama') & (BN['Year'] >= 2000)]
# Out:
#               Id   Name  Year Gender  Count
# 1614603  1614604  Obama  2008      M     14
# 1648796  1648797  Obama  2009      M     16

# %%
LSW = BN[(BN['Name'] == 'Leia') & (BN['Year'] >= 1976)]

# %%
plt.plot(LSW['Year'],LSW['Count'])

# %%
 NBAKOBE = BN[(BN['Name'] == 'Kobe') & (BN['Year'] >= 1976) & (BN['Gender']== 'M')]

# %%
plt.plot(NBAKOBE['Year'],NBAKOBE['Count'])

# %%
TENNISSER = BN[(BN['Name'] == 'Serena') & (BN['Year'] >= 1976)]

# %%
plt.plot(TENNISSER['Year'],TENNISSER['Count'])

# %%
ELVIS = BN[(BN['Name'] == 'Elvis') & (BN['Year'] >= 1950) & (BN['Year'] <= 1990) & (BN['Gender']== 'M')]

# %%
plt.plot(ELVIS['Year'],ELVIS['Count'])
plt.xlabel("Year")
plt.ylabel("Elvis")
# Out:
# Text(0, 0.5, 'Elvis')

# %%
NBALEBRON = BN[(BN['Name'] == 'Lebron') & (BN['Year'] >= 1990) & (BN['Year'] <= 2020)]

# %%
plt.plot(NBALEBRON['Year'],NBALEBRON['Count'])

# %%
BN[(BN['Name'] == 'Phoebe') & (BN['Year'] >= 1990) & (BN['Year'] <= 2020)]
# Out:
#               Id    Name  Year Gender  Count
# 1070323  1070324  Phoebe  1990      F    224
# 1095023  1095024  Phoebe  1991      F    233
# 1120253  1120254  Phoebe  1992      F    194
# 1145587  1145588  Phoebe  1993      F    214
# 1171460  1171461  Phoebe  1994      F    247
# 1197219  1197220  Phoebe  1995      F    396
# 1223260  1223261  Phoebe  1996      F    432
# 1249696  1249697  Phoebe  1997      F    419
# 1276708  1276709  Phoebe  1998      F    397
# 1304487  1304488  Phoebe  1999      F    527
# 1332978  1332979  Phoebe  2000      F    641
# 1362688  1362689  Phoebe  2001      F    752
# 1392996  1392997  Phoebe  2002      F    665
# 1423557  1423558  Phoebe  2003      F    688
# 1454699  1454700  Phoebe  2004      F    751
# 1485842  1485843  Phoebe  2004      M      5
# 1486754  1486755  Phoebe  2005      F    730
# 1519225  1519226  Phoebe  2006      F    890
# 1553268  1553269  Phoebe  2007      F    988
# 1588210  1588211  Phoebe  2008      F    959
# ...

# %%
BN[(BN['Name'] == 'Chandler') & (BN['Year'] >= 1990) & (BN['Year'] <= 2000)]
# Out:
#               Id      Name  Year Gender  Count
# 1071188  1071189  Chandler  1990      F     84
# 1085168  1085169  Chandler  1990      M    396
# 1095826  1095827  Chandler  1991      F     90
# 1110080  1110081  Chandler  1991      M    467
# 1119809  1119810  Chandler  1992      F    437
# 1135282  1135283  Chandler  1992      M    553
# 1145032  1145033  Chandler  1993      F    733
# 1160837  1160838  Chandler  1993      M    661
# 1171085  1171086  Chandler  1994      F    570
# 1186742  1186743  Chandler  1994      M    704
# 1196991  1196992  Chandler  1995      F    744
# 1212569  1212570  Chandler  1995      M   1856
# 1223203  1223204  Chandler  1996      F    493
# 1238765  1238766  Chandler  1996      M   2185
# 1249702  1249703  Chandler  1997      F    416
# 1265476  1265477  Chandler  1997      M   1796
# 1276688  1276689  Chandler  1998      F    412
# 1292868  1292869  Chandler  1998      M   1952
# 1304555  1304556  Chandler  1999      F    447
# ...

# %%
BN[(BN['Name'] == 'King') & (BN['Year'] >= 1990) & (BN['Year'] <= 2020)]
# Out:
#               Id  Name  Year Gender  Count
# 1086396  1086397  King  1990      M     47
# 1111595  1111596  King  1991      M     39
# 1136858  1136859  King  1992      M     40
# 1162434  1162435  King  1993      M     42
# 1188154  1188155  King  1994      M     50
# 1214463  1214464  King  1995      M     40
# 1240812  1240813  King  1996      M     38
# 1267301  1267302  King  1997      M     45
# 1294584  1294585  King  1998      M     52
# 1323012  1323013  King  1999      M     46
# 1351786  1351787  King  2000      M     74
# 1382055  1382056  King  2001      M     63
# 1412604  1412605  King  2002      M     57
# 1443287  1443288  King  2003      M     70
# 1474797  1474798  King  2004      M     77
# 1506617  1506618  King  2005      M    148
# 1539800  1539801  King  2006      M    217
# 1574197  1574198  King  2007      M    321
# 1609011  1609012  King  2008      M    329
# 1643533  1643534  King  2009      M    590
# 1677790  1677791  King  2010      M    703
# ...

# %%
BN[(BN['Name'] == 'Apple') & (BN['Year'] >= 1980) & (BN['Year'] <= 2020)]
# Out:
#               Id   Name  Year Gender  Count
# 874216    874217  Apple  1980      F      5
# 1131121  1131122  Apple  1992      F      6
# 1182535  1182536  Apple  1994      F      6
# 1290428  1290429  Apple  1998      F      5
# 1464259  1464260  Apple  2004      F     10
# 1489736  1489737  Apple  2005      F     44
# 1523957  1523958  Apple  2006      F     27
# 1556716  1556717  Apple  2007      F     42
# 1592877  1592878  Apple  2008      F     29
# 1627387  1627388  Apple  2009      F     33
# 1663200  1663201  Apple  2010      F     24
# 1696991  1696992  Apple  2011      F     25
# 1731059  1731060  Apple  2012      F     24
# 1764068  1764069  Apple  2013      F     28
# 1798817  1798818  Apple  2014      F     19

# %%
BN[(BN['Name'] == 'Abcde') & (BN['Year'] >= 1900) & (BN['Year'] <= 2020)]
# Out:
#               Id   Name  Year Gender  Count
# 1082408  1082409  Abcde  1990      F      5
# 1131003  1131004  Abcde  1992      F      6
# 1262859  1262860  Abcde  1997      F      5
# 1290233  1290234  Abcde  1998      F      5
# 1311223  1311224  Abcde  1999      F     13
# 1340560  1340561  Abcde  2000      F     12
# 1368914  1368915  Abcde  2001      F     16
# 1398949  1398950  Abcde  2002      F     17
# 1428530  1428531  Abcde  2003      F     22
# 1461682  1461683  Abcde  2004      F     15
# 1491923  1491924  Abcde  2005      F     22
# 1524089  1524090  Abcde  2006      F     26
# 1558629  1558630  Abcde  2007      F     24
# 1593000  1593001  Abcde  2008      F     28
# 1627471  1627472  Abcde  2009      F     32
# 1663003  1663004  Abcde  2010      F     25
# 1697771  1697772  Abcde  2011      F     21
# 1732360  1732361  Abcde  2012      F     18
# 1766524  1766525  Abcde  2013      F     16
# 1801851  1801852  Abcde  2014      F     11

# %%
BN[(BN['Name'] == 'Rihanna') & (BN['Year'] >= 1900) & (BN['Year'] <= 2020)]
# Out:
#               Id     Name  Year Gender  Count
# 1347151  1347152  Rihanna  2000      F      6
# 1488621  1488622  Rihanna  2005      F     79
# 1519391  1519392  Rihanna  2006      F    571
# 1553346  1553347  Rihanna  2007      F    788
# 1588174  1588175  Rihanna  2008      F   1072
# 1622453  1622454  Rihanna  2008      M      5
# 1623296  1623297  Rihanna  2009      F    823
# 1658176  1658177  Rihanna  2010      F    500
# 1692360  1692361  Rihanna  2011      F    380
# 1726334  1726335  Rihanna  2012      F    320
# 1760141  1760142  Rihanna  2013      F    264
# 1793577  1793578  Rihanna  2014      F    204

# %%
BN[(BN['Name'] == 'Danger') & (BN['Year'] >= 1900) & (BN['Year'] <= 2020)]
# Out:
#               Id    Name  Year Gender  Count
# 1655947  1655948  Danger  2009      M      5
# 1690032  1690033  Danger  2010      M      5
# 1753251  1753252  Danger  2012      M      9
# 1790885  1790886  Danger  2013      M      5
# 1821250  1821251  Danger  2014      M      7

# %%
BN[(BN['Name'] == 'Izzie') & (BN['Year'] >= 1990) & (BN['Year'] <= 2020)]
# Out:
#               Id   Name  Year Gender  Count
# 1537090  1537091  Izzie  2006      F      5
# 1569173  1569174  Izzie  2007      F      6
# 1595737  1595738  Izzie  2008      F     16
# 1630063  1630064  Izzie  2009      F     18
# 1667019  1667020  Izzie  2010      F     12
# 1700992  1700993  Izzie  2011      F     12
# 1733861  1733862  Izzie  2012      F     14
# 1769691  1769692  Izzie  2013      F     10
# 1803637  1803638  Izzie  2014      F      9

# %%
BN[(BN['Name'] == 'Athena') & (BN['Year'] >= 1960) & (BN['Year'] <= 2020)]
# Out:
#               Id    Name  Year Gender  Count
# 573284    573285  Athena  1960      F    151
# 585237    585238  Athena  1961      F    149
# 597373    597374  Athena  1962      F    159
# 609673    609674  Athena  1963      F    129
# 621874    621875  Athena  1964      F    150
# 634304    634305  Athena  1965      F    127
# 646229    646230  Athena  1966      F    135
# 658287    658288  Athena  1967      F    163
# 670662    670663  Athena  1968      F    176
# 683606    683607  Athena  1969      F    176
# 697331    697332  Athena  1970      F    200
# 712064    712065  Athena  1971      F    220
# 727318    727319  Athena  1972      F    228
# 742756    742757  Athena  1973      F    218
# 758359    758360  Athena  1974      F    253
# 774614    774615  Athena  1975      F    252
# 791580    791581  Athena  1976      F    232
# 808944    808945  Athena  1977      F    266
# 827109    827110  Athena  1978      F    269
# 845164    845165  Athena  1979      F    445
# ...

# %%
BN[(BN['Name'] == 'Whitney') & (BN['Year'] >= 1980) & (BN['Year'] <= 1990)]
# Out:
#               Id     Name  Year Gender  Count
# 863956    863957  Whitney  1980      F   1169
# 876634    876635  Whitney  1980      M    141
# 883380    883381  Whitney  1981      F   1302
# 896113    896114  Whitney  1981      M    135
# 902827    902828  Whitney  1982      F   1478
# 915665    915666  Whitney  1982      M    154
# 922485    922486  Whitney  1983      F   1688
# 935051    935052  Whitney  1983      M    166
# 941841    941842  Whitney  1984      F   2288
# 954486    954487  Whitney  1984      M    201
# 961289    961290  Whitney  1985      F   3833
# 974284    974285  Whitney  1985      M    236
# 981323    981324  Whitney  1986      F   9532
# 994675    994676  Whitney  1986      M    245
# 1001963  1001964  Whitney  1987      F   8923
# 1015915  1015916  Whitney  1987      M    155
# 1023365  1023366  Whitney  1988      F   7848
# 1038095  1038096  Whitney  1988      M    115
# 1045741  1045742  Whitney  1989      F   6308
# ...

# %%
BN[(BN['Name'] == 'Judy') & (BN['Year'] >= 1935) & (BN['Year'] <= 1960)]
# Out:
#             Id  Name  Year Gender  Count
# 321617  321618  Judy  1935      F   1474
# 330624  330625  Judy  1936      F   1987
# 338387  338388  Judy  1936      M      7
# 339492  339493  Judy  1937      F   2741
# 346601  346602  Judy  1937      M     11
# 348387  348388  Judy  1938      F   4993
# 354929  354930  Judy  1938      M     19
# 357403  357404  Judy  1939      F   8083
# 363405  363406  Judy  1939      M     36
# 366310  366311  Judy  1940      F  11381
# 372307  372308  Judy  1940      M     43
# 375271  375272  Judy  1941      F  13964
# 381114  381115  Judy  1941      M     65
# 384354  384355  Judy  1942      F  15669
# 390589  390590  Judy  1942      M     57
# 393776  393777  Judy  1943      F  17379
# 400054  400055  Judy  1943      M     52
# 403181  403182  Judy  1944      F  17117
# 409251  409252  Judy  1944      M     57
# 412336  412337  Judy  1945      F  17003
# 418489  418490  Judy  1945      M     49
# 421359  421360  Judy  1946      F  20478
# ...

# %%
BN[(BN['Name'] == 'Bella') & (BN['Year'] >= 1990) & (BN['Year'] <= 2020)]
# Out:
#               Id   Name  Year Gender  Count
# 1073169  1073170  Bella  1990      F     28
# 1096759  1096760  Bella  1991      F     47
# 1122249  1122250  Bella  1992      F     39
# 1147223  1147224  Bella  1993      F     49
# 1172505  1172506  Bella  1994      F     76
# 1198138  1198139  Bella  1995      F    105
# 1224684  1224685  Bella  1996      F     72
# 1250792  1250793  Bella  1997      F     95
# 1277293  1277294  Bella  1998      F    156
# 1305078  1305079  Bella  1999      F    183
# 1333286  1333287  Bella  2000      F    307
# 1362910  1362911  Bella  2001      F    412
# 1392988  1392989  Bella  2002      F    682
# 1423440  1423441  Bella  2003      F    971
# 1454554  1454555  Bella  2004      F   1240
# 1486537  1486538  Bella  2005      F   1659
# 1519043  1519044  Bella  2006      F   1953
# 1553089  1553090  Bella  2007      F   2249
# 1587984  1587985  Bella  2008      F   2782
# 1621044  1621045  Bella  2008      M      5
# ...

# %%
BN[(BN['Name'] == 'Miley') & (BN['Year'] >= 2000) & (BN['Year'] <= 2020)]
# Out:
#               Id   Name  Year Gender  Count
# 1343985  1343986  Miley  2000      F      8
# 1371453  1371454  Miley  2001      F     11
# 1400705  1400706  Miley  2002      F     13
# 1427890  1427891  Miley  2003      F     27
# 1460707  1460708  Miley  2004      F     19
# 1491386  1491387  Miley  2005      F     26
# 1520087  1520088  Miley  2006      F    197
# 1553209  1553210  Miley  2007      F   1232
# 1587990  1587991  Miley  2008      F   2648
# 1623096  1623097  Miley  2009      F   1731
# 1657809  1657810  Miley  2010      F   1437
# 1691948  1691949  Miley  2011      F    990
# 1725842  1725843  Miley  2012      F    927
# 1759573  1759574  Miley  2013      F    797
# 1793181  1793182  Miley  2014      F    352

# %%
BN[(BN['Name'] == 'Elsa') & (BN['Year'] >= 2000) & (BN['Year'] <= 2020)]
# Out:
#               Id  Name  Year Gender  Count
# 1333447  1333448  Elsa  2000      F    240
# 1363218  1363219  Elsa  2001      F    246
# 1393384  1393385  Elsa  2002      F    283
# 1423853  1423854  Elsa  2003      F    349
# 1455107  1455108  Elsa  2004      F    308
# 1487090  1487091  Elsa  2005      F    350
# 1519647  1519648  Elsa  2006      F    349
# 1553672  1553673  Elsa  2007      F    392
# 1588584  1588585  Elsa  2008      F    411
# 1623589  1623590  Elsa  2009      F    425
# 1658192  1658193  Elsa  2010      F    487
# 1692211  1692212  Elsa  2011      F    499
# 1726051  1726052  Elsa  2012      F    540
# 1759713  1759714  Elsa  2013      F    564
# 1792674  1792675  Elsa  2014      F   1131

# %%
BN[(BN['Name'] == 'Ariel') & (BN['Year'] >= 1988) & (BN['Year'] <= 2000)]
# Out:
#               Id   Name  Year Gender  Count
# 1023603  1023604  Ariel  1988      F    910
# 1037693  1037694  Ariel  1988      M    343
# 1045894  1045895  Ariel  1989      F   1284
# 1060715  1060716  Ariel  1989      M    383
# 1069545  1069546  Ariel  1990      F   3604
# 1085164  1085165  Ariel  1990      M    405
# 1094230  1094231  Ariel  1991      F   5409
# 1109984  1109985  Ariel  1991      M    665
# 1119355  1119356  Ariel  1992      F   3961
# 1135345  1135346  Ariel  1992      M    456
# 1144805  1144806  Ariel  1993      F   2707
# 1160958  1160959  Ariel  1993      M    440
# 1170787  1170788  Ariel  1994      F   2186
# 1186874  1186875  Ariel  1994      M    444
# 1196789  1196790  Ariel  1995      F   2150
# 1212876  1212877  Ariel  1995      M    447
# 1222881  1222882  Ariel  1996      F   1923
# 1239069  1239070  Ariel  1996      M    469
# 1249282  1249283  Ariel  1997      F   2212
# 1265776  1265777  Ariel  1997      M    442
# ...

# %%
BN[(BN['Name'] == 'Narnia') & (BN['Year'] >= 1988) & (BN['Year'] <= 2020)]
# Out:
#               Id    Name  Year Gender  Count
# 1535389  1535390  Narnia  2006      F      6

# %%
BN[(BN['Name'] == 'Jackson') & (BN['Year'] >= 1990) & (BN['Year'] <= 2020)]
# Out:
#               Id     Name  Year Gender  Count
# 1081374  1081375  Jackson  1990      F      6
# 1085002  1085003  Jackson  1990      M    791
# 1109864  1109865  Jackson  1991      M   1176
# 1130168  1130169  Jackson  1992      F      7
# 1135096  1135097  Jackson  1992      M   1362
# 1153687  1153688  Jackson  1993      F      9
# 1160677  1160678  Jackson  1993      M   1537
# 1184894  1184895  Jackson  1994      F      5
# 1186560  1186561  Jackson  1994      M   1934
# 1205676  1205677  Jackson  1995      F      9
# 1212553  1212554  Jackson  1995      M   2161
# 1229596  1229597  Jackson  1996      F     13
# 1238743  1238744  Jackson  1996      M   2643
# 1259306  1259307  Jackson  1997      F      8
# 1265416  1265417  Jackson  1997      M   3126
# 1282272  1282273  Jackson  1998      F     16
# 1292795  1292796  Jackson  1998      M   3859
# 1311893  1311894  Jackson  1999      F     12
# 1321014  1321015  Jackson  1999      M   4994
# ...

# %%
BN[(BN['Name'] == 'Katniss') & (BN['Year'] >= 1900) & (BN['Year'] <= 2020)]
# Out:
#               Id     Name  Year Gender  Count
# 1734870  1734871  Katniss  2012      F     12
# 1766371  1766372  Katniss  2013      F     17
# 1796317  1796318  Katniss  2014      F     38

# %%
BN[(BN['Name'] == 'Arya') & (BN['Year'] >= 2000) & (BN['Year'] <= 2020)]
# Out:
#               Id  Name  Year Gender  Count
# 1336279  1336280  Arya  2000      F     34
# 1352363  1352364  Arya  2000      M     46
# 1365937  1365938  Arya  2001      F     36
# 1382417  1382418  Arya  2001      M     48
# 1395342  1395343  Arya  2002      F     54
# 1412200  1412201  Arya  2002      M     79
# 1425467  1425468  Arya  2003      F     71
# 1443042  1443043  Arya  2003      M     86
# 1455911  1455912  Arya  2004      F    120
# 1474676  1474677  Arya  2004      M     84
# 1488068  1488069  Arya  2005      F    113
# 1507153  1507154  Arya  2005      M     82
# 1520283  1520284  Arya  2006      F    159
# 1540358  1540359  Arya  2006      M    106
# 1554173  1554174  Arya  2007      F    199
# 1574988  1574989  Arya  2007      M    105
# 1589092  1589093  Arya  2008      F    205
# 1609746  1609747  Arya  2008      M    114
# 1623985  1623986  Arya  2009      F    236
# 1644542  1644543  Arya  2009      M    113
# 1658533  1658534  Arya  2010      F    273
# ...

# %%
BN[(BN['Name'] == 'Daenerys') & (BN['Year'] >= 2000) & (BN['Year'] <= 2020)]
# Out:
#               Id      Name  Year Gender  Count
# 1731636  1731637  Daenerys  2012      F     21
# 1761774  1761775  Daenerys  2013      F     68
# 1794571  1794572  Daenerys  2014      F     86

# %%
BN[(BN['Name'] == 'Tyrion') & (BN['Year'] >= 1900) & (BN['Year'] <= 2020)]
# Out:
#               Id    Name  Year Gender  Count
# 1276016  1276017  Tyrion  1997      M      5
# 1288470  1288471  Tyrion  1998      F      7
# 1303905  1303906  Tyrion  1998      M      5
# 1328767  1328768  Tyrion  1999      M      8
# 1356473  1356474  Tyrion  2000      M     11
# 1387166  1387167  Tyrion  2001      M     10
# 1416016  1416017  Tyrion  2002      M     14
# 1447074  1447075  Tyrion  2003      M     14
# 1478579  1478580  Tyrion  2004      M     15
# 1511355  1511356  Tyrion  2005      M     14
# 1545778  1545779  Tyrion  2006      M     12
# 1579716  1579717  Tyrion  2007      M     14
# 1614032  1614033  Tyrion  2008      M     16
# 1648600  1648601  Tyrion  2009      M     17
# 1684929  1684930  Tyrion  2010      M     11
# 1716339  1716340  Tyrion  2011      M     18
# 1749803  1749804  Tyrion  2012      M     20
# 1781124  1781125  Tyrion  2013      M     43
# 1813696  1813697  Tyrion  2014      M     60

# %%
BN[(BN['Name'] == 'Aragorn') & (BN['Year'] >= 1900) & (BN['Year'] <= 2020)]
# Out:
#               Id     Name  Year Gender  Count
# 710699    710700  Aragorn  1970      M      5
# 921387    921388  Aragorn  1982      M      5
# 1421425  1421426  Aragorn  2002      M      5
# 1452542  1452543  Aragorn  2003      M      5
# 1478624  1478625  Aragorn  2004      M     14
# 1513164  1513165  Aragorn  2005      M      9

# %%
BN[(BN['Name'] == 'Arwen') & (BN['Year'] >= 1900) & (BN['Year'] <= 2020)]
# Out:
#               Id   Name  Year Gender  Count
# 676994    676995  Arwen  1968      F      5
# 690394    690395  Arwen  1969      F      5
# 700473    700474  Arwen  1970      F     15
# 715328    715329  Arwen  1971      F     15
# 730758    730759  Arwen  1972      F     14
# 746962    746963  Arwen  1973      F     11
# 761178    761179  Arwen  1974      F     19
# 776874    776875  Arwen  1975      F     25
# 794209    794210  Arwen  1976      F     21
# 811034    811035  Arwen  1977      F     30
# 828957    828958  Arwen  1978      F     35
# 847707    847708  Arwen  1979      F     28
# 866436    866437  Arwen  1980      F     34
# 886103    886104  Arwen  1981      F     30
# 905824    905825  Arwen  1982      F     27
# 927797    927798  Arwen  1983      F     12
# 946208    946209  Arwen  1984      F     16
# 968824    968825  Arwen  1985      F      8
# 986275    986276  Arwen  1986      F     15
# 1009334  1009335  Arwen  1987      F      9
# ...

# %%
BN[(BN['Name'] == 'Legolas') & (BN['Year'] >= 1900) & (BN['Year'] <= 2020)]
# Out:
#               Id     Name  Year Gender  Count
# 1450778  1450779  Legolas  2003      M      7

# %%
BN[(BN['Name'] == 'Samwise') & (BN['Year'] >= 1900) & (BN['Year'] <= 2020)]
# Out:
#               Id     Name  Year Gender  Count
# 1421065  1421066  Samwise  2002      M      6
# 1452178  1452179  Samwise  2003      M      6
# 1485988  1485989  Samwise  2004      M      5
# 1657184  1657185  Samwise  2009      M      5
# 1790236  1790237  Samwise  2013      M      6
# 1820854  1820855  Samwise  2014      M      8

# %%
BN[(BN['Name'] == 'Merida') & (BN['Year'] >= 1900) & (BN['Year'] <= 2020)]
# Out:
#               Id    Name  Year Gender  Count
# 133317    133318  Merida  1916      F      6
# 185856    185857  Merida  1921      F      5
# 218093    218094  Merida  1924      F      5
# 268935    268936  Merida  1929      F      7
# 298158    298159  Merida  1932      F      6
# 306928    306929  Merida  1933      F      7
# 326152    326153  Merida  1935      F      5
# 334116    334117  Merida  1936      F      7
# 342277    342278  Merida  1937      F     10
# 353122    353123  Merida  1938      F      5
# 361478    361479  Merida  1939      F      6
# 370487    370488  Merida  1940      F      6
# 379103    379104  Merida  1941      F      7
# 387973    387974  Merida  1942      F      8
# 396740    396741  Merida  1943      F     11
# 416699    416700  Merida  1945      F      6
# 435684    435685  Merida  1947      F      7
# 445918    445919  Merida  1948      F      7
# 454610    454611  Merida  1949      F     13
# 476127    476128  Merida  1951      F      9
# ...

# %%
BN[(BN['Name'] == 'Kanye') & (BN['Year'] >= 1900) & (BN['Year'] <= 2020)]
# Out:
#               Id   Name  Year Gender  Count
# 1422226  1422227  Kanye  2002      M      5
# 1443035  1443036  Kanye  2003      M     87
# 1460643  1460644  Kanye  2004      F     19
# 1473602  1473603  Kanye  2004      M    507
# 1504104  1504105  Kanye  2005      F      5
# 1506397  1506398  Kanye  2005      M    202
# 1540408  1540409  Kanye  2006      M    101
# 1575904  1575905  Kanye  2007      M     53
# 1610116  1610117  Kanye  2008      M     81
# 1645200  1645201  Kanye  2009      M     64
# 1680966  1680967  Kanye  2010      M     30
# 1714372  1714373  Kanye  2011      M     35
# 1748231  1748232  Kanye  2012      M     34
# 1781237  1781238  Kanye  2013      M     40
# 1815884  1815885  Kanye  2014      M     22

# %%
BN[(BN['Name'] == 'Channing') & (BN['Year'] >= 2000) & (BN['Year'] <= 2020)]
# Out:
#               Id      Name  Year Gender  Count
# 1334915  1334916  Channing  2000      F     65
# 1352239  1352240  Channing  2000      M     49
# 1364899  1364900  Channing  2001      F     58
# 1382032  1382033  Channing  2001      M     64
# 1395277  1395278  Channing  2002      F     56
# 1412801  1412802  Channing  2002      M     49
# 1426081  1426082  Channing  2003      F     51
# 1443860  1443861  Channing  2003      M     46
# 1457299  1457300  Channing  2004      F     52
# 1475762  1475763  Channing  2004      M     40
# 1488673  1488674  Channing  2005      F     76
# 1507636  1507637  Channing  2005      M     57
# 1521342  1521343  Channing  2006      F     74
# 1541125  1541126  Channing  2006      M     57
# 1555364  1555365  Channing  2007      F     77
# 1574943  1574944  Channing  2007      M    109
# 1590401  1590402  Channing  2008      F     74
# 1609635  1609636  Channing  2008      M    129
# 1624950  1624951  Channing  2009      F    100
# ...

# %%
BN[(BN['Name'] == 'Jensen') & (BN['Year'] >= 1990) & (BN['Year'] <= 2020)]
# Out:
#               Id    Name  Year Gender  Count
# 1071865  1071866  Jensen  1990      F     51
# 1086024  1086025  Jensen  1990      M     69
# 1096766  1096767  Jensen  1991      F     47
# 1111093  1111094  Jensen  1991      M     60
# 1121262  1121263  Jensen  1992      F     69
# 1136480  1136481  Jensen  1992      M     55
# 1146679  1146680  Jensen  1993      F     70
# 1162207  1162208  Jensen  1993      M     50
# 1172281  1172282  Jensen  1994      F     92
# 1187877  1187878  Jensen  1994      M     64
# 1197987  1197988  Jensen  1995      F    122
# 1213747  1213748  Jensen  1995      M     76
# 1223799  1223800  Jensen  1996      F    171
# 1239925  1239926  Jensen  1996      M     83
# 1250160  1250161  Jensen  1997      F    188
# 1266630  1266631  Jensen  1997      M     84
# 1277090  1277091  Jensen  1998      F    204
# 1293663  1293664  Jensen  1998      M    143
# 1305134  1305135  Jensen  1999      F    172
# 1321995  1321996  Jensen  1999      M    128
# ...

# %%
MT[MT['type']== 'SHOW']
# Out:
#             id                                         title  type  \
# 0     ts300399           Five Came Back: The Reference Films  SHOW
# 5      ts22164                  Monty Python's Flying Circus  SHOW
# 26     ts45948              Monty Python's Fliegender Zirkus  SHOW
# 35     ts20681                                      Seinfeld  SHOW
# 44     ts22082                                  Knight Rider  SHOW
# ...        ...                                           ...   ...
# 5828  ts319608  The Family That Sings Together: The Camargos  SHOW
# 5830  ts288861                                     Let's Eat  SHOW
# 5831  ts273317                                 Pitta Kathalu  SHOW
# 5833  ts307884                                    HQ Barbers  SHOW
# 5849  ts271048            Mighty Little Bheem: Kite Festival  SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# ...

# %%
MT[(MT['type'] == 'SHOW') & (MT['release_year'] >= 2000) & (MT['release_year'] <= 2020)]
# Out:
#             id                            title  type  \
# 91     ts20981                         Survivor  SHOW
# 110    ts21567                    Gilmore Girls  SHOW
# 121    ts21034                         InuYasha  SHOW
# 151    ts21581                      Girlfriends  SHOW
# 165    ts28516                           Okupas  SHOW
# ...        ...                              ...   ...
# 4672   ts90643                    Cairo's Class  SHOW
# 4675  ts304136                          마법버스 타요  SHOW
# 4680  ts223454                    นางสาวก้นครัว  SHOW
# 4688  ts222362      Mighty Little Bheem: Diwali  SHOW
# 4691  ts224956  What the Love! with Karan Johar  SHOW
#
#                                             description  release_year  \
# 91    A reality show contest where sixteen or more c...          2000
# 110   Set in the charming town of Stars Hollow, Conn...          2000
# 121   Kagome Higurashi is a modern day young girl wh...          2000
# ...
